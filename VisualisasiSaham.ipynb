# %% [markdown]
# <a href="https://colab.research.google.com/github/fawazdhianabil/Basic-Python-Programming-for-Data-Science/blob/main/VisualisasiSaham.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
df_bbca
# Out:
#            Date     Open     High      Low    Close     Adj Close    Volume
# 0    2020-03-13  27800.0  27800.0  27800.0  27800.0  26868.416016         0
# 1    2020-03-16  27800.0  27800.0  27800.0  27800.0  26868.416016         0
# 2    2020-03-17  27475.0  27525.0  25600.0  25600.0  24742.136719  42440000
# 3    2020-03-18  25600.0  26900.0  23825.0  25000.0  24162.244141  36010700
# 4    2020-03-19  24975.0  24975.0  23250.0  23250.0  22470.886719  52883800
# ..          ...      ...      ...      ...      ...           ...       ...
# 234  2021-03-05  33600.0  34625.0  33600.0  34000.0  33529.984375  22374300
# 235  2021-03-08  34750.0  34750.0  33600.0  33600.0  33135.515625  18176600
# 236  2021-03-09  33500.0  33575.0  33000.0  33025.0  32568.462891  27116400
# 237  2021-03-10  33600.0  33600.0  33100.0  33525.0  33061.550781  10060400
# 238  2021-03-12  34375.0  34400.0  33575.0  33825.0  33357.402344  14865600
#
# [239 rows x 7 columns]

# %%
#Visualisasi Saham BBCA
#memili dataset
df_bbca = pd.read_csv('/content/drive/MyDrive/saham/BBCA.JK.csv')

#Memasukkan dataset dan 2 variabel
figure = px.scatter(df_bbca,
                    y = df_bbca['Open'],
                    x = df_bbca['Date'])
#Mengupdate fitur yang dibutuhkan
figure.update_layout(
    title='BBCA Stock Dataset', 
    title_font_color='#f3cec9',
    title_font_size=25,              
    xaxis=dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    yaxis=dict(
        title='Open Price',
        titlefont_size=16,
        tickfont_size=14))

#Menampilkan plot
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f82c27cf-ea6a-495b-971e-932c50028940" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f82c27cf-ea6a-495b-971e-932c50028940")) {
#                     Plotly.newPlot(
#                         'f82c27cf-ea6a-495b-971e-932c50028940',
# ...
